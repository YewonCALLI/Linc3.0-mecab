# %% [markdown]
# ##Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
from pathlib import Path

# %%
delete = ["동의대학교 LINC 3.0 사업단", "신산업 중심 산학협력 기반의 인력양성과 자립화를 통한 기업가형 대학", "LINC 3.0 사업단 _", "한남대학교(충청권/수요맞춤성장형), Hannam University",
          "전북대학교 ┃", "┃JBNU LINC 3.0", "▶ KYUNG HEE UNIVERSITY", "∙"]

# %%
# bfr_data_dir = Path('/content/drive/MyDrive/2023/preprocessing/new')
bfr_data_dir = Path('/content/drive/MyDrive/4-1/study/report_utf')
bfr_files = list(bfr_data_dir.rglob('*txt'))

# %%
bfr_files
# Out:
# [PosixPath('/content/drive/MyDrive/4-1/study/report_utf/ajou.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/sogang.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/chungbuk.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/wonguang.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/gyeongseong.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/erica.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/chosun.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/korea.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/dankuk.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/dongguk.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/chungang.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/youngnam.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/report_utf/donga.txt'),
# ...

# %%
len(bfr_files)
# Out:
# 72

# %%
for file_path in bfr_files:
  with open(file_path, 'r', encoding='utf-8') as f:
    lines = [x.rstrip('\n') for x in f.readlines()]
    sentences = [re.sub(r"[*❍o§※!「」『』·【】Ÿ▣■▪➜‣⚪⦁○◯󰊳¡➡❚󰊱∙●◉□◦]", "", line) for line in lines if line != '' and line != '\n' and line != ' ' and line != "  " and line != "   "]
  with open('/content/drive/MyDrive/4-1/study/new/' + file_path.name, 'w', encoding='utf-8') as f:
    for line in sentences:
        f.write(''.join(line) + '\n')
    print(file_path.name)
# Out:
# ajou.txt
# sogang.txt
# chungbuk.txt
# wonguang.txt
# gyeongseong.txt
# erica.txt
# chosun.txt
# korea.txt
# dankuk.txt
# dongguk.txt
# chungang.txt
# youngnam.txt
# donga.txt
# chungnam.txt
# hanyang.txt
# hannam.txt
# dongeui.txt
# inha.txt
# sungkyunkwan.txt
# kyungpook.txt
# jeonnam.txt
# jeonju.txt
# pusan.txt
# jeonbuk.txt
# kookmin.txt
# kyunghee.txt
# postech.txt
# ulsan.txt
# gwangju.txt
# handong.txt
# kangwon.txt
# soonchunhyang.txt
# hoseo.txt
# hanbat.txt
# daegu.txt
# woosuk.txt
# injae.txt
# jeju.txt
# dongsu.txt
# gyemyung.txt
# dongsin.txt
# sinla.txt
# katolik.txt
# dongmyung.txt
# wonju.txt
# gyeongnam.txt
# honam.txt
# sunmoon.txt
# mokpoocean.txt
# daejun.txt
# koreaocean.txt
# incheon.txt
# weduck.txt
# koreatraffic.txt
# woosong.txt
# gyandong.txt
# koreaengineeringedu.txt
# gyeongil.txt
# koreaenginnering.txt
# boogyung.txt
# changwon.txt
# dongkook(wise).txt
# gongjoo.txt
# gumoo.txt
# hanlim.txt
# hansu.txt
# korea_sejong.txt
# kyungsang.txt
# mokpo.txt
# ...

# %%
# aft_data_dir = Path('/content/drive/MyDrive/2023/preprocessing/okt/report/new/')
aft_data_dir = Path('/content/drive/MyDrive/4-1/study/new/')
aft_files = list(aft_data_dir.rglob('*txt'))

# %%
aft_files
# Out:
# [PosixPath('/content/drive/MyDrive/4-1/study/new/ajou.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/sogang.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/wonguang.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/chungbuk.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/gyeongseong.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/erica.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/chosun.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/korea.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/dankuk.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/dongguk.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/chungang.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/youngnam.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/donga.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/chungnam.txt'),
#  PosixPath('/content/drive/MyDrive/4-1/study/new/hanyang.txt'),
# ...

# %%
aft_sentences = []

for file_path in aft_files:
  with open(file_path, 'r', encoding='UTF8') as f:
    lines = [x.rstrip('\n') for x in f.readlines()]
  # sentences = [re.sub('[^A-Za-z0-9가-힣]', '', line) for line in lines if line.isdigit() == False ]
  sentences = [re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", '', line) for line in lines if line.isdigit() == False ]
  aft_sentences.append(sentences)

# %% [markdown]
# ##Tokenize

# %%
# !apt-get update
# !apt-get install -y git make curl xz-utils file
# !apt-get install -y mecab libmecab-dev mecab-ipadic-utf8 python3-dev
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,563 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 41.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.8/493.8 kB 37.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://bitbucket.org/eunjeon/mecab-ko.git
# !cd mecab-ko && ./autogen.sh && ./configure && make && make install

# !git clone https://bitbucket.org/eunjeon/mecab-ko-dic.git
# !cd mecab-ko-dic && ./autogen.sh && ./configure && make && make install
# Out:
# Cloning into 'mecab-ko'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (296/296), done.
# remote: Compressing objects: 100% (247/247), done.
# remote: Total 296 (delta 73), reused 227 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (296/296), 1.36 MiB | 2.81 MiB/s, done.
# Resolving deltas: 100% (73/73), done.
# /bin/bash: line 1: ./autogen.sh: No such file or directory
# Cloning into 'mecab-ko-dic'...
# remote: Enumerating objects: 2011, done.
# remote: Counting objects: 100% (2011/2011), done.
# remote: Compressing objects: 100% (1079/1079), done.
# remote: Total 2011 (delta 1328), reused 1415 (delta 918), pack-reused 0 (from 0)
# Receiving objects: 100% (2011/2011), 36.14 MiB | 5.73 MiB/s, done.
# Resolving deltas: 100% (1328/1328), done.
# /bin/bash: line 1: ./autogen.sh: No such file or directory

# %%
# !pip3 install mecab-python3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.7/581.7 kB 12.3 MB/s eta 0:00:00
# ...

# %%
# !wget https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# !tar -zxvf mecab-*-ko-*.tar.gz
# !cd mecab-0.996-ko-0.9.2 && ./configure && make && make check && sudo make install
# Out:
# --2025-01-02 02:53:44--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.142.25, 104.192.142.26, 104.192.142.24, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.142.25|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !git clone https://bitbucket.org/eunjeon/mecab-python-0.996.git
# !cd mecab-python-0.996 && python3 setup.py build && python3 setup.py install
# Out:
# Cloning into 'mecab-python-0.996'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 17 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 59.67 KiB | 656.00 KiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Traceback (most recent call last):
#   File "/content/mecab-python-0.996/setup.py", line 12, in <module>
#     setup(name = "mecab-python",
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/core.py", line 145, in setup
#     _setup_distribution = dist = klass(attrs)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/dist.py", line 294, in __init__
#     self.metadata.version = self._normalize_version(self.metadata.version)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/dist.py", line 330, in _normalize_version
#     normalized = str(Version(version))
# ...

# %% [markdown]
# # 사용자 단어 추가

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
# Out:
# --2025-01-02 02:55:44--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/g8l6dlu5a3ebovcdymluq/mecab-0.996-ko-0.9.2.tar.gz?rlkey=xlooryouhr1l2ufqbt93ohfvy&dl=1 [following]
# --2025-01-02 02:55:44--  https://www.dropbox.com/scl/fi/g8l6dlu5a3ebovcdymluq/mecab-0.996-ko-0.9.2.tar.gz?rlkey=xlooryouhr1l2ufqbt93ohfvy&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucdbe38b0457dfa463028b032e31.dl.dropboxusercontent.com/cd/0/inline/ChYWd20WLO_GGcVD4UfZC5W83Tuxe-zPapssdElfAoplbQs0yOFH0On0htMbDuW9PzkbfEFftYvjMNRxPRfsCD8kqC4xc7HYV-jGJRQUlALml_5TuTF-Wf8RbvGlzu6Rn4fC_4cnLwLxRY4rW0YYjf6e/file?dl=1# [following]
# ...

# %%
# !pip3 install jamo

# %%
# !wget https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Out:
# --2025-01-02 02:58:03--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.142.25, 104.192.142.24, 104.192.142.26, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.142.25|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !tar xvfz mecab-ko-dic-2.1.1-20180720.tar.gz
# Out:
# mecab-ko-dic-2.1.1-20180720/
# mecab-ko-dic-2.1.1-20180720/configure
# mecab-ko-dic-2.1.1-20180720/COPYING
# mecab-ko-dic-2.1.1-20180720/autogen.sh
# mecab-ko-dic-2.1.1-20180720/Place-station.csv
# mecab-ko-dic-2.1.1-20180720/NNG.csv
# mecab-ko-dic-2.1.1-20180720/README
# mecab-ko-dic-2.1.1-20180720/EF.csv
# mecab-ko-dic-2.1.1-20180720/MAG.csv
# mecab-ko-dic-2.1.1-20180720/Preanalysis.csv
# mecab-ko-dic-2.1.1-20180720/NNB.csv
# mecab-ko-dic-2.1.1-20180720/Person-actor.csv
# mecab-ko-dic-2.1.1-20180720/VV.csv
# mecab-ko-dic-2.1.1-20180720/Makefile.in
# mecab-ko-dic-2.1.1-20180720/matrix.def
# mecab-ko-dic-2.1.1-20180720/EC.csv
# mecab-ko-dic-2.1.1-20180720/NNBC.csv
# mecab-ko-dic-2.1.1-20180720/clean
# mecab-ko-dic-2.1.1-20180720/ChangeLog
# mecab-ko-dic-2.1.1-20180720/J.csv
# mecab-ko-dic-2.1.1-20180720/.keep
# mecab-ko-dic-2.1.1-20180720/feature.def
# mecab-ko-dic-2.1.1-20180720/Foreign.csv
# mecab-ko-dic-2.1.1-20180720/XPN.csv
# mecab-ko-dic-2.1.1-20180720/EP.csv
# ...

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91 (from 1)
# Receiving objects: 100% (138/138), 1.72 MiB | 3.82 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
ls
# Out:
# drive/                       mecab-ko-dic/                       mecab-python-0.996/
# mecab-0.996-ko-0.9.2/        mecab-ko-dic-2.1.1-20180720/        sample_data/
# mecab-0.996-ko-0.9.2.tar.gz  mecab-ko-dic-2.1.1-20180720.tar.gz
# mecab-ko/                    Mecab-ko-for-Google-Colab/

# %%
cd Mecab-ko-for-Google-Colab/
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash ./install_mecab-ko_on_colab190912.sh
# Out:
# Installing konlpy.....
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2025-01-02 02:58:16--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.142.24, 104.192.142.26, 104.192.142.25, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.142.24|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# # 메캅 형태소 테스트

# %%
from konlpy.tag import Mecab
mecab = Mecab()
mecab.pos("산학협력 프로젝트를 실시합니다")
# Out:
# [('산학', 'NNG'),
#  ('협력', 'NNG'),
#  ('프로젝트', 'NNG'),
#  ('를', 'JKO'),
#  ('실시', 'NNG'),
#  ('합니다', 'XSV+EC')]

# %% [markdown]
# # 사용자 사전 추가하기

# %%
cd /content/mecab-ko-dic-2.1.1-20180720
# Out:
# /content/mecab-ko-dic-2.1.1-20180720

# %%
ls
# Out:
# aclocal.m4       configure.ac  IC.csv       missing*          Person.csv         user-dic/
# AUTHORS          COPYING       Inflect.csv  MM.csv            Place-address.csv  VA.csv
# autogen.sh*      dicrc         INSTALL      model.def         Place.csv          VCN.csv
# autom4te.cache/  EC.csv        install-sh*  NEWS              Place-station.csv  VCP.csv
# ChangeLog        EF.csv        J.csv        NNBC.csv          pos-id.def         VV.csv
# char.def         EP.csv        left-id.def  NNB.csv           Preanalysis.csv    VX.csv
# clean*           ETM.csv       MAG.csv      NNG.csv           README             Wikipedia.csv
# CoinedWord.csv   ETN.csv       MAJ.csv      NNP.csv           rewrite.def        XPN.csv
# config.log       feature.def   Makefile     NorthKorea.csv    right-id.def       XR.csv
# config.status*   Foreign.csv   Makefile.am  NP.csv            Symbol.csv         XSA.csv
# ...

# %%
ls user-dic
# Out:
# nnp.csv  person.csv  place.csv  README.md

# %%
ls tools
# Out:
# add-userdic.sh*  convert_for_using_store.sh*  mecab-bestn.sh*

# %% [markdown]
# # nnp.cv에 사용자 단어 추가

# %%
with open('./user-dic/nnp.csv', 'r', encoding='utf-8') as f:
  file_data = f.readlines()

# %%
file_data
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n', '구글,,,,NNP,*,T,구글,*,*,*,*,*\n']

# %%
from jamo import h2j, j2hcj

def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %%
with open('./user-dic/nnp.csv', "r", encoding='utf-8') as f:
    file_data = f.readlines()

# 단어 추가
add_list = [
    '1인당', '가족회사', '가중치', '강약점', '개발처', '거버넌스', '고부가치', '공유가치창출', '관리기능', '교과목', '교원인사', '교육', '교육원',
    '기술개발', '기술이전', '기준값', '내재화', '네트워킹', '년간', '논리모델', '단과대학', '대외협력', '대표이사', '대학내', '데이터 사이언티스트',
    '디자인', '디자인팩토리', '딥러닝', '머신러닝', '메타버스', '메타버시티', '명문 사학', '목업', '목표값', '부단장', '부전공', '부총장',
    '빅데이터', '사업팀', '산업 간', '산업군', '산업단', '산업체', '산학', '산학계', '산학연 연계', '산학연연계', '산학연협력', '산학협력',
    '산학협력단', '선도', '선도가치', '선도모델', '성과', '성과물', '성장지원', '수입료', '스마트시티', '시티 데이터', '실적물', '실효성',
    '쌍방향', '애로', '애로기술', '애로사항', '에듀테크', '여성', '연구 결과', '연구결과', '연구처', '운영체계', '유관 부서', '유관 사업',
    '유관사업', '유효성', '융복합', '융합기술', '이수학점', '이차 전지', '이차전지', '이해관계', '인력양성', '인문 사회', '인물',
    '인센티브', '인적자원', '자기주도', '자립화', '장기발전', '전략기획', '전략실', '전문교육', '전문대학원', '전임 교원', '전임교원',
    '전체', '정성분석', '제고', '조직', '조직개편', '중소벤처', '중소벤처기업진흥공단', '중위', '중장기', '중장기발전', '중장비',
    '중점', '지도사', '지산학협력', '지속가능', '지속가능성', '지역 간', '지역사회', '지원', '질적', '참여자', '참여학사', '창업',
    '창직', '창출', '첨단 신산업', '취창업', '친화형', '캠퍼스 타운', '캠퍼스타운', '캡스톤', '캡스톤 디자인', '캡스톤디자인',
    '플랫폼', '플립러닝', '한방바이오', '헬스케어', '혁신원', '현장 실습', '현장실습', '협동조합', '협의체', '홍보물', '활동물',
    '휴머니티', '휴먼팩터'
]


for word in add_list:
    jongsung_TF = get_jongsung_TF(word)
    line = '{},*,*,*,NNG,*,{},{},*,*,*,*,*\n'.format(word, jongsung_TF, word)
    file_data.append(line)

print(file_data[-10:])
# Out:
# ['헬스케어,*,*,*,NNG,*,F,헬스케어,*,*,*,*,*\n', '혁신원,*,*,*,NNG,*,T,혁신원,*,*,*,*,*\n', '현장 실습,*,*,*,NNG,*,T,현장 실습,*,*,*,*,*\n', '현장실습,*,*,*,NNG,*,T,현장실습,*,*,*,*,*\n', '협동조합,*,*,*,NNG,*,T,협동조합,*,*,*,*,*\n', '협의체,*,*,*,NNG,*,T,협의체,*,*,*,*,*\n', '홍보물,*,*,*,NNG,*,T,홍보물,*,*,*,*,*\n', '활동물,*,*,*,NNG,*,T,활동물,*,*,*,*,*\n', '휴머니티,*,*,*,NNG,*,F,휴머니티,*,*,*,*,*\n', '휴먼팩터,*,*,*,NNG,*,F,휴먼팩터,*,*,*,*,*\n']

# %%
file_data
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n',
#  '구글,,,,NNP,*,T,구글,*,*,*,*,*\n',
#  '1인당,*,*,*,NNG,*,T,1인당,*,*,*,*,*\n',
#  '가족회사,*,*,*,NNG,*,F,가족회사,*,*,*,*,*\n',
#  '가중치,*,*,*,NNG,*,F,가중치,*,*,*,*,*\n',
#  '강약점,*,*,*,NNG,*,T,강약점,*,*,*,*,*\n',
#  '개발처,*,*,*,NNG,*,F,개발처,*,*,*,*,*\n',
#  '거버넌스,*,*,*,NNG,*,F,거버넌스,*,*,*,*,*\n',
#  '고부가치,*,*,*,NNG,*,F,고부가치,*,*,*,*,*\n',
#  '공유가치창출,*,*,*,NNG,*,T,공유가치창출,*,*,*,*,*\n',
#  '관리기능,*,*,*,NNG,*,T,관리기능,*,*,*,*,*\n',
#  '교과목,*,*,*,NNG,*,T,교과목,*,*,*,*,*\n',
#  '교원인사,*,*,*,NNG,*,F,교원인사,*,*,*,*,*\n',
#  '교육,*,*,*,NNG,*,T,교육,*,*,*,*,*\n',
#  '교육원,*,*,*,NNG,*,T,교육원,*,*,*,*,*\n',
#  '기술개발,*,*,*,NNG,*,T,기술개발,*,*,*,*,*\n',
#  '기술이전,*,*,*,NNG,*,T,기술이전,*,*,*,*,*\n',
#  '기준값,*,*,*,NNG,*,T,기준값,*,*,*,*,*\n',
#  '내재화,*,*,*,NNG,*,F,내재화,*,*,*,*,*\n',
#  '네트워킹,*,*,*,NNG,*,T,네트워킹,*,*,*,*,*\n',
#  '년간,*,*,*,NNG,*,T,년간,*,*,*,*,*\n',
#  '논리모델,*,*,*,NNG,*,T,논리모델,*,*,*,*,*\n',
#  '단과대학,*,*,*,NNG,*,T,단과대학,*,*,*,*,*\n',
#  '대외협력,*,*,*,NNG,*,T,대외협력,*,*,*,*,*\n',
# ...

# %%
with open('./user-dic/nnp.csv', 'w', encoding='utf-8') as f:
  for line in file_data:
    f.write(line)

# %%
with open('./user-dic/nnp.csv', "r", encoding='utf-8') as f:
    user_dict = f.readlines()
user_dict
# Out:
# ['대우,,,,NNP,*,F,대우,*,*,*,*,*\n',
#  '구글,,,,NNP,*,T,구글,*,*,*,*,*\n',
#  '1인당,*,*,*,NNG,*,T,1인당,*,*,*,*,*\n',
#  '가족회사,*,*,*,NNG,*,F,가족회사,*,*,*,*,*\n',
#  '가중치,*,*,*,NNG,*,F,가중치,*,*,*,*,*\n',
#  '강약점,*,*,*,NNG,*,T,강약점,*,*,*,*,*\n',
#  '개발처,*,*,*,NNG,*,F,개발처,*,*,*,*,*\n',
#  '거버넌스,*,*,*,NNG,*,F,거버넌스,*,*,*,*,*\n',
#  '고부가치,*,*,*,NNG,*,F,고부가치,*,*,*,*,*\n',
#  '공유가치창출,*,*,*,NNG,*,T,공유가치창출,*,*,*,*,*\n',
#  '관리기능,*,*,*,NNG,*,T,관리기능,*,*,*,*,*\n',
#  '교과목,*,*,*,NNG,*,T,교과목,*,*,*,*,*\n',
#  '교원인사,*,*,*,NNG,*,F,교원인사,*,*,*,*,*\n',
#  '교육,*,*,*,NNG,*,T,교육,*,*,*,*,*\n',
#  '교육원,*,*,*,NNG,*,T,교육원,*,*,*,*,*\n',
#  '기술개발,*,*,*,NNG,*,T,기술개발,*,*,*,*,*\n',
#  '기술이전,*,*,*,NNG,*,T,기술이전,*,*,*,*,*\n',
#  '기준값,*,*,*,NNG,*,T,기준값,*,*,*,*,*\n',
#  '내재화,*,*,*,NNG,*,F,내재화,*,*,*,*,*\n',
#  '네트워킹,*,*,*,NNG,*,T,네트워킹,*,*,*,*,*\n',
#  '년간,*,*,*,NNG,*,T,년간,*,*,*,*,*\n',
#  '논리모델,*,*,*,NNG,*,T,논리모델,*,*,*,*,*\n',
#  '단과대학,*,*,*,NNG,*,T,단과대학,*,*,*,*,*\n',
#  '대외협력,*,*,*,NNG,*,T,대외협력,*,*,*,*,*\n',
# ...

# %% [markdown]
# # add-userdic.sh 스크립트 실행

# %%
cd /content/mecab-ko-dic-2.1.1-20180720
# Out:
# /content/mecab-ko-dic-2.1.1-20180720

# %%
ls
# Out:
# aclocal.m4       configure.ac  IC.csv       missing*          Person.csv         user-dic/
# AUTHORS          COPYING       Inflect.csv  MM.csv            Place-address.csv  VA.csv
# autogen.sh*      dicrc         INSTALL      model.def         Place.csv          VCN.csv
# autom4te.cache/  EC.csv        install-sh*  NEWS              Place-station.csv  VCP.csv
# ChangeLog        EF.csv        J.csv        NNBC.csv          pos-id.def         VV.csv
# char.def         EP.csv        left-id.def  NNB.csv           Preanalysis.csv    VX.csv
# clean*           ETM.csv       MAG.csv      NNG.csv           README             Wikipedia.csv
# CoinedWord.csv   ETN.csv       MAJ.csv      NNP.csv           rewrite.def        XPN.csv
# config.log       feature.def   Makefile     NorthKorea.csv    right-id.def       XR.csv
# config.status*   Foreign.csv   Makefile.am  NP.csv            Symbol.csv         XSA.csv
# ...

# %%
ls user-dic
# Out:
# nnp.csv  person.csv  place.csv  README.md

# %%
ls tools
# Out:
# add-userdic.sh*  convert_for_using_store.sh*  mecab-bestn.sh*

# %%
# !bash autogen.sh
# Out:
# Looking in current directory for macros.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.
# ./lib/autoconf/general.m4:2434: AC_DIAGNOSE is expanded from...
# aclocal.m4:139: AM_INIT_AUTOMAKE is expanded from...
# configure.ac:2: the top level
# configure.ac:56: warning: AC_OUTPUT should be used without arguments.
# configure.ac:56: You should run autoupdate.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.  For more info, see:
# configure.ac:2: https://www.gnu.org/software/automake/manual/automake.html#Modernize-AM_005fINIT_005fAUTOMAKE-invocation

# %%
# !make
# Out:
# /bin/bash ./config.status --recheck
# running CONFIG_SHELL=/bin/bash /bin/bash ./configure --no-create --no-recursion
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# /content/mecab-ko-dic-2.1.1-20180720/missing: Unknown `--is-lightweight' option
# Try `/content/mecab-ko-dic-2.1.1-20180720/missing --help' for more information
# configure: WARNING: 'missing' script is too old or missing
# checking for a race-free mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for mecab-config... /usr/local/bin/mecab-config
# checking that generated files are newer than configure... done
# configure: creating ./config.status
#  /bin/bash ./config.status
# config.status: creating Makefile
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# ...

# %%
# !sudo make install
# Out:
# make[1]: Entering directory '/content/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/content/mecab-ko-dic-2.1.1-20180720'

# %%
# !bash tools/add-userdic.sh
# Out:
# generating userdic...
# nnp.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/nnp.csv ...
# done!
# person.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/person.csv ...
# done!
# place.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/place.csv ...
# done!
# test -z "model.bin matrix.bin char.bin sys.dic unk.dic" || rm -f model.bin matrix.bin char.bin sys.dic unk.dic
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./MM.csv ... 453
# reading ./user-place.csv ... 2
# ...

# %%
# !make install
# Out:
# make[1]: Entering directory '/content/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/content/mecab-ko-dic-2.1.1-20180720'

# %%
from konlpy.tag import Mecab
mecab = Mecab()

print(mecab.pos('지속가능'))
print(mecab.pos('가족회사에 대해서'))
print(mecab.pos('유료가족회사에대한공용활용장비사용료할인을통해가족회사와의네트워킹강화연구장비DB가등록되어있는부산시의지산학협력센터플랫폼을활용하여공동장비수요'))
# Out:
# [('지속', 'NNG'), ('가능', 'NNG')]
# [('가족', 'NNG'), ('회사', 'NNG'), ('에', 'JKB'), ('대해서', 'VV+EC')]
# [('유료', 'NNG'), ('가족', 'NNG'), ('회사', 'NNG'), ('에', 'JKB'), ('대한', 'VV+ETM'), ('공용', 'NNG'), ('활용', 'NNG'), ('장비', 'NNG'), ('사용료', 'NNG'), ('할인', 'NNG'), ('을', 'JKO'), ('통해', 'VV+EC'), ('가족', 'NNG'), ('회사', 'NNG'), ('와', 'JKB'), ('의', 'JKG'), ('네트워킹', 'NNG'), ('강화', 'NNG'), ('연구', 'NNG'), ('장비', 'NNG'), ('DB', 'SL'), ('가', 'JKS'), ('등록', 'NNG'), ('되', 'XSV'), ('어', 'EC'), ('있', 'VX'), ('는', 'ETM'), ('부산시', 'NNP'), ('의', 'JKG'), ('지산학협력', 'NNG'), ('센터', 'NNG'), ('플랫폼', 'NNG'), ('을', 'JKO'), ('활용', 'NNG'), ('하', 'XSV'), ('여', 'EC'), ('공동', 'NNG'), ('장비', 'NNG'), ('수요', 'NNG')]

# %%
print(mecab.pos('산학연연계'))
print(mecab.pos('산학협력'))
# Out:
# [('산학연연계', 'NNG')]
# [('산학협력', 'NNG')]

# %% [markdown]
# 위의 탭이 돌아가면 mecab이 정상적으로 실행됨을 확인.
